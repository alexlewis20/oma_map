# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
# Config matplotlib plot
# %matplotlib inline
plt.rcParams['figure.figsize'] = (40, 20)
plt.rcParams['axes.titlesize'] = (30)
plt.rcParams['axes.titlepad'] = (10)
plt.rcParams['axes.labelsize'] = (20)

# %%
# Import data
filename = 'OMA-project-data.csv'
df = pd.read_csv(filename)
df = df.drop(["LINK", "TYPOLOGY_02", "@Photos", "Unnamed: 11", "IMG_", "URL STRING"], axis=1)

#add decade col
def create_decade(x):
    d = str(x['YEAR'])
    e = d[:3] + "0s"
    return e

df['DECADE'] = df.apply(create_decade, axis=1)

df.head(10)
# Out:
#                               DESCRIPTION  YEAR         TYPE  \
# 0                      Delirious New York  1978  Publication
# 1              Dutch Parliament Extension  1978      Project
# 2        Irish Prime Minister's Residence  1979      Project
# 3                                Boompjes  1980      Project
# 4  Kochstrasse / Friedrichstrasse Housing  1980      Project
# 5                Koepel Panopticon Prison  1980      Project
# 6                   Lützowstrasse Housing  1980      Project
# 7                     Parc de la Villette  1982      Project
# 8                  Exposition Universelle  1983      Project
# 9                          Churchillplein  1984      Project
#
#                STATUS     TYPOLOGY_01   REM?            TEAM_01  \
# 0         Publication             NaN   True                NaN
# 1         Competition          Office   True         Zaha Hadid
# 2         Competition          Office   True       Alan Forster
# 3  Commissioned Study     Residential   True  Kees Christiaanse
# 4         Competition     Residential   True    Herman de Kovel
# 5  Commissioned Study  Infrastructure   True         Mike Guyer
# 6         Competition     Residential  False       Norman Chang
# 7         Competition       Landscape   True  Kees Christiaanse
# 8  Design Development      Masterplan   True  Kees Christiaanse
# 9         Competition          Office   True  Kees Christiaanse
#
#                TEAM_02                TEAM_03             TEAM_04  ...    \
# 0                  NaN                    NaN                 NaN  ...
# 1  Richard Perlemutter            Ron Steiner       Elias Veneris  ...
# 2   Stefano de Martino            Ron Steiner      Elia Zenghelis  ...
# 3       Gerard Comello     Stefano de Martino       Jeroen Thomas  ...
# 4   Stefano de Martino    Richard Perlemutter    Ricardo Simonini  ...
# 5        Thijs de Haan        Vahé Kalousdian     Brigitte Kochta  ...
# 6           Omri Eytan        Katerina Galani  Andreas Kourkoulas  ...
# 7   Stefano de Martino           Ruurd Roorda         Ron Steiner  ...
# 8   Stefano de Martino  Willem-Jan Neutelings         Ron Steiner  ...
# 9       Jaap van Heest            Götz Keller       Jeroen Thomas  ...
#
#   Unnamed: 101 Unnamed: 102 Unnamed: 103 Unnamed: 104 Unnamed: 105  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
# 5          NaN          NaN          NaN          NaN          NaN
# 6          NaN          NaN          NaN          NaN          NaN
# 7          NaN          NaN          NaN          NaN          NaN
# 8          NaN          NaN          NaN          NaN          NaN
# 9          NaN          NaN          NaN          NaN          NaN
#
#   Unnamed: 106 Unnamed: 107 Unnamed: 108 Unnamed: 109 DECADE
# 0          NaN          NaN          NaN          NaN  1970s
# 1          NaN          NaN          NaN          NaN  1970s
# 2          NaN          NaN          NaN          NaN  1970s
# 3          NaN          NaN          NaN          NaN  1980s
# 4          NaN          NaN          NaN          NaN  1980s
# 5          NaN          NaN          NaN          NaN  1980s
# 6          NaN          NaN          NaN          NaN  1980s
# 7          NaN          NaN          NaN          NaN  1980s
# 8          NaN          NaN          NaN          NaN  1980s
# 9          NaN          NaN          NaN          NaN  1980s
#
# [10 rows x 105 columns]

# %%
status_dict = {
               "Commissioned Study": 1,
               "Competition": 2,
               "Completed": 4,
               "Construction": 2,
               "Demolished": 2,
               "Design Development": 2,
               "Lecture": 0,
               "Publication": 4,
               "Study": 0
               }

typology_dict = {
                 "N/A": 0,
                 "Arena": 0,
                 "Branding": 1,
                 "Education": 2,
                 "Exhibition": 2,
                 "Hotel": 2,
                 "Industrial": 0,
                 "Infrastructure": 0,
                 "Landscape": 2,
                 "Library": 3,
                 "Masterplan": 3,
                 "Mixed use": 4,
                 "Museum / Gallery": 3,
                 "Office": 0,
                 "Product Design": 0,
                 "Research": 0,
                 "Residential": 1,
                 "Restaurant / Bar": 0,
                 "Retail": 2,
                 "Scenography": 3,
                 "Theatre": 3,
                 "Tower": 0
                 }

decades_dict = {
                "1970s": 5,
                "1980s": 3,
                "1990s": 1,
                "2000s": 0
                }


dict_dict = {
            "STATUS": status_dict,
            "TYPOLOGY_01": typology_dict,
            "DECADE": decades_dict
            }

# %%
def set_value (dictionary, key):
    max_dict = max([i for i in dictionary.values()])
    x = dictionary[key] / max_dict
    return x

def importance_factor(y):
    z = []
    
    for k in dict_dict:
        try:
            m = dict_dict[k]
            n = y[k]
            z.append(set_value(m, n))
        except:
            pass
    
    a = float(len(z))
    b = float(sum(z))
    return (b/a)

# %%
df['IMPORTANCE'] = df.apply(importance_factor, axis=1)

df.sort_values("IMPORTANCE", ascending=False).head(1)
# Out:
#           DESCRIPTION  YEAR         TYPE       STATUS TYPOLOGY_01  REM?  \
# 0  Delirious New York  1978  Publication  Publication         NaN  True
#
#   TEAM_01 TEAM_02 TEAM_03 TEAM_04    ...     Unnamed: 102 Unnamed: 103  \
# 0     NaN     NaN     NaN     NaN    ...              NaN          NaN
#
#   Unnamed: 104 Unnamed: 105 Unnamed: 106 Unnamed: 107 Unnamed: 108  \
# 0          NaN          NaN          NaN          NaN          NaN
#
#   Unnamed: 109 DECADE IMPORTANCE
# 0          NaN  1970s        1.0
#
# [1 rows x 106 columns]

# %%
# Organise columns
df["TEAM LIST"] = np.nan

cols = df.columns.tolist()
cols = cols[-3:] + cols[:-3]
df = df[cols]
df.head(5)
# Out:
#   DECADE  IMPORTANCE  TEAM LIST                             DESCRIPTION  YEAR  \
# 0  1970s    1.000000        NaN                      Delirious New York  1978
# 1  1970s    0.333333        NaN              Dutch Parliament Extension  1978
# 2  1970s    0.333333        NaN        Irish Prime Minister's Residence  1979
# 3  1980s    0.000000        NaN                                Boompjes  1980
# 4  1980s    0.000000        NaN  Kochstrasse / Friedrichstrasse Housing  1980
#
#           TYPE              STATUS  TYPOLOGY_01  REM?            TEAM_01  \
# 0  Publication         Publication          NaN  True                NaN
# 1      Project         Competition       Office  True         Zaha Hadid
# 2      Project         Competition       Office  True       Alan Forster
# 3      Project  Commissioned Study  Residential  True  Kees Christiaanse
# 4      Project         Competition  Residential  True    Herman de Kovel
#
#       ...      Unnamed: 100 Unnamed: 101 Unnamed: 102 Unnamed: 103  \
# 0     ...               NaN          NaN          NaN          NaN
# 1     ...               NaN          NaN          NaN          NaN
# 2     ...               NaN          NaN          NaN          NaN
# 3     ...               NaN          NaN          NaN          NaN
# 4     ...               NaN          NaN          NaN          NaN
#
#   Unnamed: 104 Unnamed: 105 Unnamed: 106 Unnamed: 107 Unnamed: 108  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#   Unnamed: 109
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 107 columns]

# %%
team_cols = df.loc[:, 'TEAM_01':].columns.tolist()
team_cols_len = len(team_cols)

def create_team(x):
    y = []
    for i in team_cols:
        y.append(x[i])
    return y

df["TEAM LIST"] = df.apply(create_team, axis=1)

df.head(2)
# Out:
#   DECADE  IMPORTANCE                                          TEAM LIST  \
# 0  1970s    1.000000  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 1  1970s    0.333333  [Zaha Hadid, Richard Perlemutter, Ron Steiner,...
#
#                   DESCRIPTION  YEAR         TYPE       STATUS TYPOLOGY_01  \
# 0          Delirious New York  1978  Publication  Publication         NaN
# 1  Dutch Parliament Extension  1978      Project  Competition      Office
#
#    REM?     TEAM_01     ...      Unnamed: 100 Unnamed: 101 Unnamed: 102  \
# 0  True         NaN     ...               NaN          NaN          NaN
# 1  True  Zaha Hadid     ...               NaN          NaN          NaN
#
#   Unnamed: 103 Unnamed: 104 Unnamed: 105 Unnamed: 106 Unnamed: 107  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
#
#   Unnamed: 108 Unnamed: 109
# 0          NaN          NaN
# 1          NaN          NaN
#
# [2 rows x 107 columns]

# %%
team_list = df["TEAM LIST"].tolist()

def find_names(name):
    j = []

    for i in team_list:
        j.append(name in i)
    return j

def name_frame(name):
    p = find_names(name)
    q = df[p]
    return q

# %%
# Load name list
name_file = 'key-people-list.txt'
file_open = open(name_file)
c = file_open.readlines()
name_list = []
for i in c:
    y = i.strip()
    name_list.append(y)
    
print name_list
# Out:
# ['Generation-01_Christian Rapp', 'Generation-01_Edzo Bindels', 'Generation-01_Christophe Cornubert', 'Generation-01_Matthias Sauerbruch', 'Generation-01_Kees Christiaanse', 'Generation-01_Yushi Uehara', 'Generation-01_Zaha Hadid', 'Generation-01_Laurinda Spear', 'Generation-01_Ruurd Roorda', 'Generation-01_Williem Jan Neutelings', 'Generation-01_Winy Maas', 'Generation-01_Jacob Van Rijs', 'Generation-01_Sarah Whiting', 'Generation-01_Ron Witte', 'Generation-01_Mike Guyer', 'Generation-01_Alejandro Zaera Polo', 'Generation-01_Luc Reuse', 'Generation-01_Farshid Moussavi', 'Generation-01_Rients Dijkstra', 'Generation-02_Jeffery Inaba', 'Generation-02_Xaveer de Geyter', 'Generation-02_Amale Andraos', 'Generation-02_Dan Wood', 'Generation-02_Juliette Bekkering', 'Generation-02_John Mcmorrough', 'Generation-02_Matthias Hollwich', 'Generation-02_Jeanne Gang', 'Generation-02_Fernando Romero', 'Generation-02_Markus Schaefer', 'Generation-02_Zachary R.Heineman', 'Generation-02_Joshua Prince-Ramus', 'Generation-02_Erez Ella', 'Generation-02_Bjarke Ingels', 'Generation-02_Julien De Smedt', 'Generation-02_Patrick Louwere', 'Generation-02_Bart Eijking', 'Generation-02_Ole Scheeren', 'Generation-02_Eric Chang', 'Projects-01_Jeroen Thomas', 'Projects-02_Ron Steiner', 'Projects-03_Chris van Duijn', 'Projects-04_Frans Blok', 'Projects-05_Shohei Shigematsu', 'Projects-06_Reinier de Graaf', 'Projects-07_Xaveer de Geyter', 'Projects-08_Floris Alkemade', 'Projects-09_Fernando Donis', 'Projects-10_Dan Wood']

# %%
def process_names(d):
    e = d.split('_')
    f = name_frame(e[1])
    f["BRANCH KEY"] = e[1]
    f["KEY LIST"] = e[0]
    save_path = "people_output/" + d + ".csv"
    f.to_csv(save_path, index=False)
    print "Saved: " + save_path

count = 0
for g in name_list:
    process_names(g)
    count += 1
    
print "Processed: " + count
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Saved: people_output/Generation-01_Christian Rapp.csv
# Saved: people_output/Generation-01_Edzo Bindels.csv
# Saved: people_output/Generation-01_Christophe Cornubert.csv
# Saved: people_output/Generation-01_Matthias Sauerbruch.csv
# Saved: people_output/Generation-01_Kees Christiaanse.csv
# Saved: people_output/Generation-01_Yushi Uehara.csv
# Saved: people_output/Generation-01_Zaha Hadid.csv
# Saved: people_output/Generation-01_Laurinda Spear.csv
# Saved: people_output/Generation-01_Ruurd Roorda.csv
# Saved: people_output/Generation-01_Williem Jan Neutelings.csv
# Saved: people_output/Generation-01_Winy Maas.csv
# Saved: people_output/Generation-01_Jacob Van Rijs.csv
# Saved: people_output/Generation-01_Sarah Whiting.csv
# Saved: people_output/Generation-01_Ron Witte.csv
# Saved: people_output/Generation-01_Mike Guyer.csv
# Saved: people_output/Generation-01_Alejandro Zaera Polo.csv
# Saved: people_output/Generation-01_Luc Reuse.csv
# Saved: people_output/Generation-01_Farshid Moussavi.csv
# Saved: people_output/Generation-01_Rients Dijkstra.csv
# Saved: people_output/Generation-02_Jeffery Inaba.csv
# Saved: people_output/Generation-02_Xaveer de Geyter.csv
# Saved: people_output/Generation-02_Amale Andraos.csv
# Saved: people_output/Generation-02_Dan Wood.csv
# Saved: people_output/Generation-02_Juliette Bekkering.csv
# Saved: people_output/Generation-02_John Mcmorrough.csv
# Saved: people_output/Generation-02_Matthias Hollwich.csv
# Saved: people_output/Generation-02_Jeanne Gang.csv
# Saved: people_output/Generation-02_Fernando Romero.csv
# Saved: people_output/Generation-02_Markus Schaefer.csv
# Saved: people_output/Generation-02_Zachary R.Heineman.csv
# Saved: people_output/Generation-02_Joshua Prince-Ramus.csv
# Saved: people_output/Generation-02_Erez Ella.csv
# Saved: people_output/Generation-02_Bjarke Ingels.csv
# Saved: people_output/Generation-02_Julien De Smedt.csv
# Saved: people_output/Generation-02_Patrick Louwere.csv
# Saved: people_output/Generation-02_Bart Eijking.csv
# Saved: people_output/Generation-02_Ole Scheeren.csv
# Saved: people_output/Generation-02_Eric Chang.csv
# Saved: people_output/Projects-01_Jeroen Thomas.csv
# Saved: people_output/Projects-02_Ron Steiner.csv
# Saved: people_output/Projects-03_Chris van Duijn.csv
# Saved: people_output/Projects-04_Frans Blok.csv
# Saved: people_output/Projects-05_Shohei Shigematsu.csv
# Saved: people_output/Projects-06_Reinier de Graaf.csv
# Saved: people_output/Projects-07_Xaveer de Geyter.csv
# Saved: people_output/Projects-08_Floris Alkemade.csv
# Saved: people_output/Projects-09_Fernando Donis.csv
# Saved: people_output/Projects-10_Dan Wood.csv
